# %%
import cv2
import google.colab.patches as colab

# %%
in_image = cv2.imread("/content/drive/MyDrive/Colab Notebooks/lena.bmp")

# %% [markdown]
# read a pixel

# %%
p_value = in_image[20, 30]
print(f'{p_value}')
# Out:
# [117 135 226]

# %% [markdown]
# write a pixel

# %%
in_image = [255, 0, 0]

# %% [markdown]
# re-load the image

# %%
in_image = cv2.imread("/content/drive/MyDrive/Colab Notebooks/lena.bmp")

# %% [markdown]
# read a block and display block

# %%
b_block = in_image[20:40, 30:50]
colab.cv2_imshow(b_block)
# Out:
# <PIL.Image.Image image mode=RGB size=20x20 at 0x7FB69ECF5C90>

# %% [markdown]
# write a block and display in_image

# %%
in_image[20:40, 30:50] = [255, 0, 0]
colab.cv2_imshow(in_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FB69EC6F750>
